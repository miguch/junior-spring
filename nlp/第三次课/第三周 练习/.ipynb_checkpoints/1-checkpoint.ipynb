# %%
import nltk
from nltk.tokenize import sent_tokenize

# %% [markdown]
# ### 读取数据

# %%
text_en = open(u'./data/text_en.txt',encoding='utf-8',errors='ignore').read()

# %% [markdown]
# ### 切分语句

# %%
tokens = sent_tokenize(text_en)
print(len(tokens))
# Out:
# 5978

# %% [markdown]
# ### 分离缩略词实现切分词

# %%
words = nltk.word_tokenize(text_en)
print(len(words))
# Out:
# 142792

# %% [markdown]
# ### 通过分离标点实现切分词

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()
words1 = tokenizer.tokenize(text_en)
print(len(words1))
# Out:
# 143998

# %% [markdown]
# ### 提取词干

# %%
from nltk import SnowballStemmer
print(SnowballStemmer.languages)
# Out:
# ('arabic', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'porter', 'portuguese', 'romanian', 'russian', 'spanish', 'swedish')

# %%
english = SnowballStemmer('english')
for word in words:
    print('%s: %s' % (word, english.stem(word)))
# Out:
# ﻿: ﻿
# The: the
# Project: project
# Gutenberg: gutenberg
# EBook: ebook
# of: of
# Pride: pride
# and: and
# Prejudice: prejudic
# ,: ,
# by: by
# Jane: jane
# Austen: austen
# Chapter: chapter
# 1: 1
# It: it
# is: is
# a: a
# truth: truth
# universally: univers
# acknowledged: acknowledg
# ,: ,
# that: that
# a: a
# single: singl
# man: man
# in: in
# possession: possess
# of: of
# a: a
# good: good
# fortune: fortun
# ,: ,
# must: must
# be: be
# in: in
# want: want
# of: of
# a: a
# wife: wife
# .: .
# However: howev
# little: littl
# known: known
# the: the
# feelings: feel
# or: or
# views: view
# of: of
# such: such
# a: a
# man: man
# may: may
# be: be
# on: on
# his: his
# first: first
# entering: enter
# a: a
# neighbourhood: neighbourhood
# ,: ,
# this: this
# truth: truth
# is: is
# so: so
# well: well
# fixed: fix
# in: in
# the: the
# minds: mind
# of: of
# the: the
# surrounding: surround
# families: famili
# ,: ,
# that: that
# he: he
# is: is
# considered: consid
# ...

# %% [markdown]
# ### 去停用词

# %%
from nltk.corpus import stopwords
stwords = stopwords.words('english')
print(stwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
filtered = [word for word in words if word not in stwords]
print(filtered)
# Out:
# ['\ufeff', 'The', 'Project', 'Gutenberg', 'EBook', 'Pride', 'Prejudice', ',', 'Jane', 'Austen', 'Chapter', '1', 'It', 'truth', 'universally', 'acknowledged', ',', 'single', 'man', 'possession', 'good', 'fortune', ',', 'must', 'want', 'wife', '.', 'However', 'little', 'known', 'feelings', 'views', 'man', 'may', 'first', 'entering', 'neighbourhood', ',', 'truth', 'well', 'fixed', 'minds', 'surrounding', 'families', ',', 'considered', 'rightful', 'property', 'one', 'daughters', '.', '``', 'My', 'dear', 'Mr.', 'Bennet', ',', "''", 'said', 'lady', 'one', 'day', ',', '``', 'heard', 'Netherfield', 'Park', 'let', 'last', '?', "''", 'Mr.', 'Bennet', 'replied', '.', '``', 'But', ',', "''", 'returned', ';', '``', 'Mrs.', 'Long', ',', 'told', '.', "''", 'Mr.', 'Bennet', 'made', 'answer', '.', '``', 'Do', 'want', 'know', 'taken', '?', "''", 'cried', 'wife', 'impatiently', '.', '``', 'You', 'want', 'tell', ',', 'I', 'objection', 'hearing', '.', "''", 'This', 'invitation', 'enough', '.', '``', 'Why
# ...

# %% [markdown]
# ### 去标点符号
