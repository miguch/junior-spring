# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms, utils, datasets

from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm

import numpy as np
import pandas as pd
import sklearn
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
# !nvidia-smi
# Out:
# Thu Jun 13 14:40:01 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.66       Driver Version: 410.66       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  On   | 00000000:43:00.0 Off |                  N/A |
# |  0%   52C    P0    81W / 260W |      0MiB / 10988MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## load image

# %%
class ImageFolderWithPaths(datasets.ImageFolder):
    """Custom dataset that includes image file paths. Extends
    torchvision.datasets.ImageFolder
    """

    # override the __getitem__ method. this is the method dataloader calls
    def __getitem__(self, index):
        # this is what ImageFolder normally returns 
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        # the image file path
        path = self.imgs[index][0]
        # make a new tuple that includes original and the path
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path

# %%
import os
transform = transforms.Compose([transforms.CenterCrop(224),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5])])

data_image = {x:ImageFolderWithPaths(root = os.path.join('./data/image',x),
                                     transform = transform)
              for x in ["train", "test", 'eval']}
batch_size = 32
data_loader_image = {x:torch.utils.data.DataLoader(dataset=data_image[x],
                                                batch_size = batch_size,
                                                shuffle = True)
                     for x in ["train", "test", 'eval']}

# %%
data_loader_image
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x7f28cf2cf4a8>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x7f28cf2cf6a0>,
#  'eval': <torch.utils.data.dataloader.DataLoader at 0x7f28cf2cf710>}

# %%
X_train, y_train, X_name = next(iter(data_loader_image["train"]))
mean = [0.5,0.5,0.5]
std  = [0.5,0.5,0.5]
img = torchvision.utils.make_grid(X_train)
img = img.numpy().transpose((1,2,0))
img = img*std+mean

print(X_name)
print([i for i in y_train])
plt.imshow(img)
# Out:
# ('./data/image/train/0/1452745987_0.jpg', './data/image/train/4/1024656920_0.jpg', './data/image/train/5/1381732466_0.jpg', './data/image/train/4/1443628295_0.jpg', './data/image/train/6/1308755864_0.jpg', './data/image/train/0/1450592462_0.jpg', './data/image/train/5/1448154454_0.jpg', './data/image/train/3/1036900728_0.jpg', './data/image/train/7/1374681700_0.jpg', './data/image/train/5/1227109619_0.jpg', './data/image/train/7/1037316747_0.jpg', './data/image/train/6/1036672955_0.jpg', './data/image/train/1/1566683072_0.jpg', './data/image/train/2/1026153570_0.jpg', './data/image/train/0/1473856693_0.jpg', './data/image/train/7/1219369204_0.jpg', './data/image/train/7/1231290235_0.jpg', './data/image/train/3/1341494404_0.jpg', './data/image/train/7/1030520177_0.jpg', './data/image/train/3/10113770583_0.jpg', './data/image/train/4/1087983220_0.jpg', './data/image/train/1/1133172312_0.jpg', './data/image/train/2/1568976287_0.jpg', './data/image/train/6/1366046722_0.jpg', './data/image/train/1/1019462405_0.jpg', './data/image/train/2/1011607955_0.jpg', './data/image/train/7/1357019846_0.jpg', './data/image/train/7/1235122978_0.jpg', './data/image/train/3/1118566250_0.jpg', './data/image/train/0/1252186858_0.jpg', './data/image/train/3/1445349750_0.jpg', './data/image/train/4/1493311855_0.jpg')
# [tensor(0), tensor(4), tensor(5), tensor(4), tensor(6), tensor(0), tensor(5), tensor(3), tensor(7), tensor(5), tensor(7), tensor(6), tensor(1), tensor(2), tensor(0), tensor(7), tensor(7), tensor(3), tensor(7), tensor(3), tensor(4), tensor(1), tensor(2), tensor(6), tensor(1), tensor(2), tensor(7), tensor(7), tensor(3), tensor(0), tensor(3), tensor(4)]

# %%
net = torchvision.models.resnet152(pretrained=True)
net.fc = torch.nn.Linear(2048, 8)
net = net.to(device)

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.00001)
epoch = 10

# %%
def train():
    net.train()
    total_loss = 0
    for image, label, name in tqdm(data_loader_image['train'], leave=False):
        image = image.to(device)
        label = label.to(device)
        optimizer.zero_grad()

        target = net(image)
        loss = criterion(target, label)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    for image, label, name in tqdm(data_loader_image['eval'], leave=False):
        image = image.to(device)
        label = label.to(device)
        optimizer.zero_grad()

        target = net(image)
        loss = criterion(target, label)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    return total_loss/float(len(data_loader_image['train']) + len(data_loader_image['eval']))

# %%
for i in tqdm(range(epoch)):
    print(train())
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=529), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=130), HTML(value='')))
# 0.012679307492081024
# HBox(children=(IntProgress(value=0, max=529), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=130), HTML(value='')))
# 0.0068239196193403085
# HBox(children=(IntProgress(value=0, max=529), HTML(value='')))

# %%
torch.save(net, 'train_model.pkl')

# %%
net = torch.load('train_model.pkl').to(device)

# %%
validation_set = torch.utils.data.DataLoader(dataset=data_image["eval"],
                                                batch_size = 20,
                                                shuffle = False)
def evaluate():
    net.eval()
    corrects = eval_loss = 0

    for image, label, name in tqdm(validation_set, leave=False):
        image = image.to(device)
        label = label.to(device) 
        pred = net(image)
        loss = criterion(pred, label)

        eval_loss += loss.item()
        corrects += (torch.max(pred, 1)[1].view(label.size()).data == label.data).sum()
    return eval_loss/float(len(data_loader_image['eval'])), corrects, corrects*100/batch_size/len(data_loader_image['eval'])

# %%
evaluate()
# Out:
# HBox(children=(IntProgress(value=0, max=207), HTML(value='')))
# (0.004724658170068953,
#  tensor(4128, device='cuda:0'),
#  tensor(99, device='cuda:0'))

# %%
test_set = torch.utils.data.DataLoader(dataset=data_image["test"],
                                                batch_size = 1,
                                                shuffle = False)

# %%
def test():
    net.eval()
    corrects = eval_loss = 0
    result = []
    for image, label, name in tqdm(test_set):
        image = image.to(device)
        label = label.to(device) 
        pred = net(image)
        
        result.append([name, torch.max(pred, 1)[1].view(label.size()).data])
    return result

# %%
results = test()
# Out:
# HBox(children=(IntProgress(value=0, max=4500), HTML(value='')))

# %%
processed_res = []
for r in results:
    path = r[0][0].split('/')[-1]
    cloth = r[1][0].item()
    processed_res.append([path, cloth])

# %%
res_df = pd.DataFrame(processed_res)
res_df.columns = ['Image', 'Cloth_label']

# %%
res_df['Cloth_label'].unique()
# Out:
# array([7, 3, 0, 5, 1, 4, 2, 6])

# %%
res_df.to_csv('res.csv', index=False)
